# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

np.random.seed(0)
x = np.random.rand(100, 1)
y = 3+5 * x

print('first 5 data on x' ,  x[:5], 'first 5 data on y' , y[:5])

lr_regress = LinearRegression()

lr_regress.fit(x, y)

y_pred = lr_regress.predict(x)

mae = mean_absolute_error(y, y_pred)
mse = mean_squared_error(y, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y, y_pred)

print('Slope', lr_regress.coef_)
print('Intercept', lr_regress.intercept_)
print('Mean absolute error', mae)
print('Mean squared error', mse)
print('Root Mean Squared error', rmse)
print('R2', r2)
# Out:
# first 5 data on x [[0.5488135 ]
#  [0.71518937]
#  [0.60276338]
#  [0.54488318]
#  [0.4236548 ]] first 5 data on y [[5.74406752]
#  [6.57594683]
#  [6.01381688]
#  [5.72441591]
#  [5.118274  ]]
# Slope [[5.]]
# Intercept [3.]
# Mean absolute error 9.237055564881303e-16
# Mean squared error 1.0846837446788912e-30
# Root Mean Squared error 1.041481514324134e-15
# R2 1.0

# %%
plt.scatter(x, y, s=10)
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x, y_pred, color='red')
plt.show()
